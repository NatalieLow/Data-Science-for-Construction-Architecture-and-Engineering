# %% [markdown]
# <a href="https://colab.research.google.com/github/NatalieLow/Data-Science-for-Construction-Architecture-and-Engineering/blob/main/Copy_of_Exercise_4_2_Pandas_Stats_and_Viz_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science for Construction, Architecture and Engineering
#
# ### Section 4 - Operations - Pandas Statistics and Visualization
#
# ### Exercise Set 4.2 - Pandas Stats and Viz II
#
# This set of exercises is related to the second half of Section 4 videos. Using the same data (ASBRAE Thermal Comfort Database II) and packages (Pandas) as in the videos, we will learn how to find specific values in different scenarios.
#
# There is an introduction video available to explain the process of using this exercise video.
#
# The lead developer of this exercise is Chun Fu, a Ph.D. student at NUS and a teaching assistant of this course.

# %% [markdown]
# #### Setup the environment
#
# Let's set up the environment and read the data first:

# %%
# Import packages
import pandas as pd
from google.colab import drive
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Set path for data source
drive.mount('/content/gdrive')
os.chdir("/content/gdrive/My Drive/EDX Data Science for Construction, Architecture and Engineering/4 - Operations - Statistics and Visualization/")
# Out:
# Mounted at /content/gdrive

# %%
# Load thermal comfort database
ieq_data = pd.read_csv("ashrae_thermal_comfort_database_2.csv", index_col='Unnamed: 0')

# %% [markdown]
# ## Boxplot Example in Seaborn
#
# Before we get into the exercises, let's look at an example of how we can use boxplots to compare distributions between different groups. In the figure below, we have created a visualization that shows the **Air temperature (C)** has significantly different distributions under different **Thermal sensation**.
#
# For example, **Air temperature (C)** with the lowest **ThermalSensation_rounded** value (-3.0) has the distribution of lower values (seeing the boxplot body that covers 50% of the data).

# %%
# Boxplot for Air temperature (C) under different Thermal sensation
fig, ax = plt.subplots()
fig.set_size_inches(10,6)
sns.boxplot(x="ThermalSensation_rounded", y="Air temperature (C)", data=ieq_data)

# %% [markdown]
# ## Exercise 04.2.1 -- Which country has the lowest median relative humidity?
#
# After the example shown above, you should be more familiar with how to use boxplot in Seaborn package!
#
# Now, imagine you are an environmental researcher who mainly studies **humidity conditions** of our surrounding environments, especially focusing on where the **lowest** relative humidity happens.
#
# So, in our first exercise, let's begin with considering only one variable (or column) - **Country**. In terms of **median**, find the country with the lowest **Relative humidity (%)**, according to the dataset (for example, **Singapore** could be one of possible answers).
#
#  You are encouraged to draw boxplots of **Relative humidity (%)** for each of the different **Country**, just like the example we demonstrated.
#
# **Note**: All measurements in `ASHRAE Thermal Comfort Database II` were collected from field experiments research projects, including indoor and outdoor environments, so they might not represent the local climate or general indoor condition.

# %%
# Try to use the seaborn example from above. If the x-axis labels are too hard to read, try to adjust the parameters in set_size_inches() or switch X and Y axis
# YOUR CODE HERE 
fig, ax = plt.subplots()
fig.set_size_inches(10,10)

sns.boxplot(x="Relative humidity (%)", y="Country", data=ieq_data)

ieq_data.groupby(['Country', 'Season']).head()
# Out:
#                                    Publication (Citation)    Year  Season  \
# 2233    Indraganti, Madhavi, et al. "Adaptive model of...  2012.0  Winter
# 2234    Indraganti, Madhavi, et al. "Adaptive model of...  2012.0  Winter
# 2235    Indraganti, Madhavi, et al. "Adaptive model of...  2012.0  Winter
# 2236    Indraganti, Madhavi, et al. "Adaptive model of...  2012.0  Winter
# 2237    Indraganti, Madhavi, et al. "Adaptive model of...  2012.0  Winter
# ...                                                   ...     ...     ...
# 102202  de Dear, R. J., Leow, K. G. and S. C. Foo (199...  1987.0  Autumn
# 102203  de Dear, R. J., Leow, K. G. and S. C. Foo (199...  1987.0  Autumn
# 102204  de Dear, R. J., Leow, K. G. and S. C. Foo (199...  1987.0  Autumn
# 102205  de Dear, R. J., Leow, K. G. and S. C. Foo (199...  1987.0  Autumn
# 102206  de Dear, R. J., Leow, K. G. and S. C. Foo (199...  1987.0  Autumn
#
#                      Climate       City    Country Building type  \
# 2233    Tropical wet savanna    Chennai      India        Office
# 2234    Tropical wet savanna    Chennai      India        Office
# 2235    Tropical wet savanna    Chennai      India        Office
# 2236    Tropical wet savanna    Chennai      India        Office
# 2237    Tropical wet savanna    Chennai      India        Office
# ...                      ...        ...        ...           ...
# 102202   Tropical rainforest  Singapore  Singapore        Office
# 102203   Tropical rainforest  Singapore  Singapore        Office
# 102204   Tropical rainforest  Singapore  Singapore        Office
# 102205   Tropical rainforest  Singapore  Singapore        Office
# 102206   Tropical rainforest  Singapore  Singapore        Office
#
#        Cooling startegy_building level     Sex  Thermal sensation   Clo   Met  \
# 2233                        Mixed Mode  Female               -2.0  0.75  1.00
# 2234                        Mixed Mode    Male               -1.0  0.64  1.00
# 2235                        Mixed Mode    Male               -2.0  0.64  1.00
# 2236                        Mixed Mode  Female               -2.0  0.75  1.00
# 2237                        Mixed Mode    Male                0.0  0.72  1.00
# ...                                ...     ...                ...   ...   ...
# 102202            Naturally Ventilated  Female                1.0  0.53  1.60
# 102203            Naturally Ventilated    Male                1.5  0.28  1.46
# 102204            Naturally Ventilated  Female                1.5  0.35  1.31
# 102205            Naturally Ventilated  Female                1.0  0.34  1.18
# 102206            Naturally Ventilated    Male                1.0  0.28  1.21
#
#         Air temperature (C)  Relative humidity (%)  Air velocity (m/s)  \
# 2233                   25.2                   64.0                0.10
# 2234                   25.2                   64.0                0.10
# 2235                   25.2                   64.0                0.10
# 2236                   25.2                   64.0                0.10
# 2237                   25.2                   64.0                0.10
# ...                     ...                    ...                 ...
# 102202                 29.3                   84.4                0.09
# 102203                 29.3                   88.5                0.09
# 102204                 29.7                   85.9                0.09
# 102205                 29.3                   88.5                0.09
# 102206                 29.3                   88.5                0.09
#
#         ThermalSensation_rounded
# 2233                        -2.0
# 2234                        -1.0
# 2235                        -2.0
# 2236                        -2.0
# 2237                         0.0
# ...                          ...
# 102202                       1.0
# 102203                       2.0
# 102204                       2.0
# 102205                       1.0
# 102206                       1.0
#
# [275 rows x 16 columns]

# %% [markdown]
# ## Exercise 04.2.2 - Which country and season has the lowest median relative humidity?
#
# In 4.2.1, we got the lowest median relative humidity among different countries. However, the distribution of humidity is also strongly affected by different seasons. Therefore, in this exercise, please consider both **Country** and **Season** at the same time to find the lowest median **Relative humidity (%)**.
#
# Find the country and season with the lowest **median** **Relative humidity (%)** (for example, **Singapore-Summer** could be one of possible answers).

# %%
# If the x-axis labels are too hard to read, try to adjust the parameters in set_size_inches() or switch X and Y axis
# YOUR CODE HERE
fig, ax = plt.subplots()
fig.set_size_inches(10,10)

ieq_data['country_season'] = ieq_data['Country'] + "_" + ieq_data['Season'] 


sns.boxplot(x="Relative humidity (%)", y= 'country_season', data=ieq_data)
ieq_data.info()

median_humidity = ieq_data.groupby('country_season')['Relative humidity (%)'].describe(percentiles=[0.5]).reset_index()
median_humidity.sort_values('50%', ascending=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43448 entries, 2233 to 104033
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Publication (Citation)           43448 non-null  object
#  1   Year                             43448 non-null  float64
#  2   Season                           43448 non-null  object
#  3   Climate                          43448 non-null  object
#  4   City                             43448 non-null  object
#  5   Country                          43448 non-null  object
#  6   Building type                    43448 non-null  object
#  7   Cooling startegy_building level  43448 non-null  object
#  8   Sex                              43448 non-null  object
#  9   Thermal sensation                43448 non-null  float64
#  10  Clo                              43448 non-null  float64
#  11  Met                              43448 non-null  float64
#  12  Air temperature (C)              43448 non-null  float64
#  13  Relative humidity (%)            43448 non-null  float64
#  14  Air velocity (m/s)               43448 non-null  float64
#  15  ThermalSensation_rounded         43448 non-null  float64
#  16  country_season                   43448 non-null  object
#  17  country_season_bldgType          43448 non-null  object
# dtypes: float64(8), object(10)
# memory usage: 7.3+ MB
#         country_season   count       mean        std   min    50%   max
# 44       Sweden_Winter   125.0  20.464000   6.105714  11.6  19.40  35.1
# 11       Canada_Winter   311.0  20.405466   7.102026  10.0  20.60  34.8
# 27        Italy_Spring    60.0  24.121667   7.553854  14.0  21.10  37.4
# 9        Canada_Spring   115.0  24.284348   5.717035  15.8  22.80  39.2
# 29        Italy_Winter    73.0  26.147945   3.334171  18.6  27.30  32.0
# 42       Sweden_Spring   247.0  30.519838   6.624546   0.5  29.60  51.1
# 15       France_Winter   169.0  30.923077   7.185849   6.1  30.60  50.4
# 19       Greece_Summer   776.0  33.829639   7.749531   2.0  33.50  54.0
# 20       Greece_Winter    21.0  33.185714   2.088130  26.6  33.60  35.9
# 17       Greece_Autumn   380.0  36.355000  11.059339   4.0  34.90  66.0
# 52          USA_Spring   718.0  36.976323   8.853793  17.6  36.75  57.2
# 41       Sweden_Autumn   361.0  38.945429  11.976244  19.0  36.80  62.5
# 22        India_Spring  2818.0  38.480908  11.298078  10.3  37.00  72.0
# 51          USA_Autumn   121.0  35.213223   7.545406  23.1  38.50  48.4
# 26        Italy_Autumn    13.0  39.323077   2.571366  33.0  39.70  41.3
# 54          USA_Winter   987.0  38.526241   8.807460  20.3  39.70  61.6
# 18       Greece_Spring   106.0  42.242453   7.222385  28.8  41.35  66.2
# 13       France_Spring    61.0  41.504918   6.498626  20.0  41.90  54.9
# 50           UK_Winter   245.0  40.602041   6.148913  23.9  42.00  66.3
# 14       France_Summer    61.0  43.560656   7.685664  30.7  42.60  60.2
# 8        Canada_Autumn     6.0  42.483333   1.506541  40.3  42.75  44.8
# 10       Canada_Summer   435.0  45.068966   7.676619  29.5  42.90  62.2
# 47           UK_Autumn   719.0  42.844924  10.060679  13.5  43.30  83.1
# 24        India_Winter  4982.0  44.619169  11.774353  14.5  45.00  79.0
# 0     Australia_Autumn   278.0  45.719424   7.248671  31.0  45.05  69.8
# 12       France_Autumn   174.0  42.289080  11.910123  16.1  45.95  68.7
# 49           UK_Summer   629.0  45.862003   8.303497  16.7  46.00  67.8
# 34  Philippines_Summer   277.0  47.368592   7.105228  29.3  46.20  72.0
# 3     Australia_Winter  1413.0  47.276008   9.921159  21.2  46.60  71.5
# 43       Sweden_Summer   207.0  47.424638   5.825898  31.3  47.90  61.5
# 16      Germany_Summer   414.0  48.612560  10.369187  23.8  48.20  72.2
# 21        India_Autumn  1586.0  49.738714  13.063053  15.9  49.00  95.3
# 37     Portugal_Summer   277.0  48.939350   7.080183  29.1  49.10  64.2
# 1     Australia_Spring    45.0  48.773333  10.982101  26.9  49.60  64.6
# 28        Italy_Summer    83.0  48.393976   8.849230  23.7  49.60  66.5
# 38     Portugal_Winter   457.0  49.956674   7.782882  27.9  50.50  68.5
# 36     Portugal_Spring   288.0  50.850000   8.126886  31.3  50.65  69.3
# 2     Australia_Summer  5204.0  51.442083   9.925773  18.4  52.00  78.4
# 35     Portugal_Autumn   536.0  53.195336   8.221794  28.5  53.80  75.3
# 48           UK_Spring   463.0  52.076242   8.854663  21.8  54.50  67.1
# 23        India_Summer  5805.0  58.100724  13.475984  15.7  57.50  90.1
# 53          USA_Summer  1124.0  59.542171   7.114297  30.7  59.90  77.9
# 7        Brazil_Winter  2521.0  61.124117   8.979505  38.7  62.20  82.3
# 45     Thailand_Spring   601.0  63.477371  10.584386  34.8  62.50  88.3
# 25         Iran_Winter   377.0  61.959947   7.838164  36.4  63.00  79.9
# 6        Brazil_Summer  1381.0  61.397031   5.437429  49.3  63.30  78.1
# 46     Thailand_Summer   545.0  64.345688  10.636770  33.6  63.60  93.8
# 4        Brazil_Autumn  2339.0  67.397435  10.092511  47.9  65.60  88.8
# 5        Brazil_Spring   833.0  68.605522   8.482317  23.0  67.30  83.6
# 40    Singapore_Summer   798.0  68.172431  10.555802  35.6  69.40  97.8
# 32     Malaysia_Summer   171.0  68.601754   6.399361  53.2  69.80  82.3
# 30     Malaysia_Autumn   216.0  69.782407   5.018159  57.0  70.00  83.0
# 31     Malaysia_Spring   231.0  70.336364   6.112423  56.2  70.80  86.4
# 33     Malaysia_Winter   251.0  74.049801   5.462281  59.3  74.30  85.9
# 39    Singapore_Autumn    14.0  83.635714   4.128439  78.9  84.40  88.5

# %% [markdown]
# ## Exercise 04.2.3 - Which country, season, and building type, has the lowest median relative humidity? - Advanced
#
# Based on the problems above, we can get the minimum relative humidity by taking into account both the **Country** and the **Season**. However, **Building type** is also an important factor influencing the indoor environment, and we should consider this as well. In addition, some subsets in the `ASHRAE Thermal Comfort Database II` have rows with incomplete data that might not give a reliable result, so they should be removed.
#
# So, in this exercise, we want to (1) consider three conditions at the same time: **Country**, **Season** and **Building type**, and (2) **remove the subset with less than 100 rows** (e.g., the subset Sweden-Winter-Classroom with only 54 data rows should be removed).
#
# Find the **Country**, **Season**, and **Building type** with the lowest `median` **Relative humidity (%)**
#
# Please provide the answer in the following format: "country-season-building type", with the first letter capitalized, for example, **Singapore-Summer-Office**

# %%
from pandas.core.ops.array_ops import is_integer_dtype
# Create a dataframe of counts by using groupby(by=['var1','var2','var3']), and put list of variables as parameter in function
# YOUR CODE HERE
ieq_data['country_season_bldgType'] = ieq_data['Country'] + "_" + ieq_data['Season'] + "_" + ieq_data['Building type']
counts_list = ieq_data['country_season_bldgType'].value_counts()
# print(counts_list.size)
trimmed_list = counts_list[counts_list >= 100]
# print(trimmed_list.index)

# min100data = ieq_data[ieq_data['country_season_bldgType'].map(ieq_data['country_season_bldgType'].value_counts()) == 100] 
# min100data.head()
trimmed_data = ieq_data[ieq_data['country_season_bldgType'].isin(trimmed_list.index)]
trimmed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41304 entries, 2233 to 104033
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Publication (Citation)           41304 non-null  object
#  1   Year                             41304 non-null  float64
#  2   Season                           41304 non-null  object
#  3   Climate                          41304 non-null  object
#  4   City                             41304 non-null  object
#  5   Country                          41304 non-null  object
#  6   Building type                    41304 non-null  object
#  7   Cooling startegy_building level  41304 non-null  object
#  8   Sex                              41304 non-null  object
#  9   Thermal sensation                41304 non-null  float64
#  10  Clo                              41304 non-null  float64
#  11  Met                              41304 non-null  float64
#  12  Air temperature (C)              41304 non-null  float64
#  13  Relative humidity (%)            41304 non-null  float64
#  14  Air velocity (m/s)               41304 non-null  float64
#  15  ThermalSensation_rounded         41304 non-null  float64
#  16  country_season                   41304 non-null  object
#  17  country_season_bldgType          41304 non-null  object
# dtypes: float64(8), object(10)
# memory usage: 6.0+ MB

# %%
# Create a dataframe of medians by using groupby(by=listOfVariable), where listOfVariable is a list of variable names
# YOUR CODE HERE
trimmed_median_humidity = trimmed_data.groupby('country_season_bldgType')['Relative humidity (%)'].describe(percentiles=[0.5]).reset_index()
trimmed_median_humidity.sort_values('50%', ascending=True)
# Out:
#                 country_season_bldgType   count       mean        std   min  \
# 14                 Canada_Winter_Others   274.0  20.889416   6.831209  10.0
# 21     India_Spring_Multifamily housing   311.0  24.297749   7.923022  10.4
# 12                 Canada_Spring_Others   115.0  24.284348   5.717035  15.8
# 17                 Greece_Autumn_Office   255.0  32.044314   8.493756   4.0
# 41                 Sweden_Spring_Others   152.0  30.881579   7.659392   0.5
# 18                 Greece_Summer_Office   715.0  33.708951   7.736749   2.0
# 23                  India_Spring_Others   629.0  33.395548   5.078359  13.9
# 52                    USA_Spring_Office   718.0  36.976323   8.853793  17.6
# 19     India_Autumn_Multifamily housing   394.0  44.252792  21.130759  15.9
# 51                    USA_Autumn_Office   121.0  35.213223   7.545406  23.1
# 54                    USA_Winter_Office   987.0  38.526241   8.807460  20.3
# 27     India_Winter_Multifamily housing   533.0  43.171670  12.931243  16.5
# 15              France_Autumn_Classroom   102.0  39.215686  12.546529  16.1
# 40                 Sweden_Autumn_Others   187.0  37.919786  11.559932  19.0
# 50                     UK_Winter_Others   245.0  40.602041   6.148913  23.9
# 22                  India_Spring_Office  1878.0  42.532907  10.684167  10.3
# 44                  UK_Autumn_Classroom   374.0  41.386631  11.752738  13.5
# 4        Australia_Winter_Senior center   214.0  44.157944  10.686027  24.7
# 13                 Canada_Summer_Others   396.0  45.618434   7.752376  29.5
# 45                     UK_Autumn_Others   345.0  44.425797   7.528072  31.6
# 47                     UK_Spring_Others   174.0  43.764368   6.686108  21.8
# 49                     UK_Summer_Others   342.0  44.981287   5.732861  29.8
# 28                  India_Winter_Office  4355.0  44.813479  11.708604  14.5
# 34            Philippines_Summer_Office   277.0  47.368592   7.105228  29.3
# 3               Australia_Winter_Office  1199.0  47.832527   9.677939  21.2
# 48                  UK_Summer_Classroom   287.0  46.911498  10.496552  16.7
# 0               Australia_Autumn_Office   234.0  47.427778   6.487085  32.0
# 16                Germany_Summer_Office   414.0  48.612560  10.369187  23.8
# 37               Portugal_Summer_Others   228.0  48.707018   7.441244  29.1
# 38               Portugal_Winter_Others   360.0  48.487778   7.284487  27.9
# 36               Portugal_Spring_Others   239.0  50.263180   7.880376  34.1
# 20                  India_Autumn_Office  1192.0  51.552013   8.155437  29.0
# 1               Australia_Summer_Office  4998.0  51.330112  10.000427  18.4
# 35               Portugal_Autumn_Others   455.0  52.159121   8.382920  28.5
# 26                  India_Summer_Others   115.0  53.744348  12.856019  26.9
# 2        Australia_Summer_Senior center   206.0  54.158738   7.417520  25.8
# 25                  India_Summer_Office  5428.0  57.886035  13.178966  20.9
# 46                  UK_Spring_Classroom   289.0  57.080623   5.661300  39.3
# 11                 Brazil_Winter_Office  1361.0  58.428655  10.385832  38.7
# 53                    USA_Summer_Office  1124.0  59.542171   7.114297  30.7
# 42               Thailand_Spring_Office   601.0  63.477371  10.584386  34.8
# 29                   Iran_Winter_Office   377.0  61.959947   7.838164  36.4
# 9               Brazil_Summer_Classroom  1298.0  61.666410   5.121298  51.1
# 43               Thailand_Summer_Office   545.0  64.345688  10.636770  33.6
# 6                  Brazil_Autumn_Office   886.0  64.758804   6.651624  47.9
# 8                  Brazil_Spring_Office   378.0  64.488360   5.369224  23.0
# 10              Brazil_Winter_Classroom  1160.0  64.286638   5.495637  56.2
# 5               Brazil_Autumn_Classroom  1453.0  69.006401  11.410801  49.3
# 24     India_Summer_Multifamily housing   262.0  64.460687  17.459039  15.7
# 39              Singapore_Summer_Office   798.0  68.172431  10.555802  35.6
# 32  Malaysia_Summer_Multifamily housing   171.0  68.601754   6.399361  53.2
# 30  Malaysia_Autumn_Multifamily housing   216.0  69.782407   5.018159  57.0
# 31  Malaysia_Spring_Multifamily housing   231.0  70.336364   6.112423  56.2
# 33  Malaysia_Winter_Multifamily housing   251.0  74.049801   5.462281  59.3
# 7               Brazil_Spring_Classroom   455.0  72.025934   9.059660  56.7
#
#       50%   max
# 14  20.95  34.8
# 21  22.10  63.9
# 12  22.80  39.2
# 17  29.30  52.7
# 41  29.50  51.1
# 18  33.30  54.0
# 23  34.00  59.5
# 52  36.75  57.2
# 19  37.25  95.3
# 51  38.50  48.4
# 54  39.70  61.6
# 27  40.10  79.0
# 15  40.65  61.1
# 40  40.90  61.9
# 50  42.00  66.3
# 22  42.00  72.0
# 44  42.45  83.1
# 4   42.90  63.2
# 13  43.35  62.2
# 45  44.40  68.1
# 47  44.90  67.1
# 49  44.90  60.5
# 28  45.00  73.2
# 34  46.20  72.0
# 3   47.00  71.5
# 48  47.30  67.8
# 0   47.55  69.8
# 16  48.20  72.2
# 37  48.70  64.2
# 38  49.05  68.5
# 36  49.70  69.3
# 20  50.00  73.0
# 1   51.80  78.4
# 35  52.50  75.3
# 26  52.90  86.6
# 2   54.30  68.9
# 25  57.00  88.8
# 46  58.30  66.5
# 11  58.40  82.3
# 53  59.90  77.9
# 42  62.50  88.3
# 29  63.00  79.9
# 9   63.40  77.0
# 43  63.60  93.8
# 6   64.65  82.1
# 8   65.80  76.2
# 10  66.40  73.2
# 5   68.80  88.8
# 24  68.95  90.1
# 39  69.40  97.8
# 32  69.80  82.3
# 30  70.00  83.0
# 31  70.80  86.4
# 33  74.30  85.9
# 7   74.90  83.6

# %%
# Use dataframe of counts as filter (keep subsets with more or equal than 100 data rows) and find the lowest value
# YOUR CODE HERE

# %% [markdown]
# ### **Please note that you will need to use the resultant output from Exercise 04.2.3 for the Quiz 4.2.**
# **(The answer should follow the format:"country-season-building type", with the first letter capitalized, for example, Singapore-Summer-Office)**
